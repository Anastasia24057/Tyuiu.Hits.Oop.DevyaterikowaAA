// %% [markdown]
// <h1 style="color:DodgerBlue">Структура и объявление класса, через: свойства, геттеры и сеттеры</h1>

// %% [markdown]
// ### Структура и Объявление Класса в C#
//
// В C#, класс объявляется с использованием ключевого слова `class`, за которым следует имя класса. Класс может содержать поля (данные), свойства (способ доступа к данным), методы (функциональность) и события.
//
// #### Свойства
//
// Свойства в C# используются для инкапсуляции данных. Они предоставляют гибкий механизм для чтения, записи или вычисления значений приватных полей. Свойства могут иметь два акцессора: `get` (геттер) для чтения значения и `set` (сеттер) для его изменения.
//
// #### Геттеры и Сеттеры
//
// Геттеры и сеттеры являются частью свойств класса в C#. Геттер (`get`) используется для возврата значения свойства, а сеттер (`set`) — для установки нового значения. Сеттер может включать логику валидации или другие операции перед изменением значения поля.
//
// ### Пример Классов Vehicle и Car
//
// Давайте рассмотрим примеры классов `Vehicle` и `Car`, чтобы проиллюстрировать использование свойств, геттеров и сеттеров, а также разницу между статическими и обычными атрибутами и методами.
//
// #### Класс Vehicle
//
// ```csharp
// public class Vehicle
// {
//     private string _color;
//     private int _speed;
//
//     // Свойство Color с геттером и сеттером
//     public string Color
//     {
//         get { return _color; }
//         set { _color = value; }
//     }
//
//     // Свойство Speed с геттером и сеттером
//     public int Speed
//     {
//         get { return _speed; }
//         set
//         {
//             if (value >= 0)
//                 _speed = value;
//             else
//                 throw new ArgumentOutOfRangeException("Скорость не может быть отрицательной!");
//         }
//     }
//
//     // Статический атрибут
//     public static int TotalVehicles { get; private set; } = 0;
//
//     // Конструктор
//     public Vehicle()
//     {
//         TotalVehicles++;
//     }
//
//     // Обычный метод
//     public void Accelerate(int delta)
//     {
//         Speed += delta;
//     }
//
//     // Статический метод
//     public static void DisplayTotalVehicles()
//     {
//         Console.WriteLine($"Общее количество транспортных средств: {TotalVehicles}");
//     }
// }
// ```
//
// #### Класс Car
//
// ```csharp
// public class Car : Vehicle
// {
//     private int _fuelLevel;
//
//     // Свойство FuelLevel с геттером и сеттером
//     public int FuelLevel
//     {
//         get { return _fuelLevel; }
//         set { _fuelLevel = value; }
//     }
//
//     // Конструктор
//     public Car() : base()
//     {
//         FuelLevel = 100; // Задаем начальный уровень топлива
//     }
//
//     // Обычный метод
//     public void Refuel(int amount)
//     {
//         FuelLevel += amount;
//     }
// }
// ```
//
// ### Разница между Статическими и Обычными Атрибутами и Методами Класса
//
// - **Статические атрибуты и методы** принадлежат самому классу, а не его экземплярам. Они могут быть вызваны без создания объекта класса. В примере выше `TotalVehicles` является статическим атрибутом, а `DisplayTotalVehicles()` — статическим методом класса `Vehicle`.
// - **Обычные атрибуты и методы** принадлежат экземплярам класса и могут иметь разные значения для разных объектов. В примере выше `_color`, `_speed` и `_fuelLevel` являются обычными атрибутами, а методы `Accelerate()` и `Refuel()` — обычными методами.
//
// ### Заключение
//
// В этом таске мы рассмотрели структуру и объявление класса в C#, включая свойства, геттеры и сеттеры, а также разницу между статическими и обычными атрибутами и методами класса на примерах классов `Vehicle` и `Car`. Эти концепции являются основой для создания объектно-ориентированных программ на C#.

// %% [markdown]
// <h4 style="color:DodgerBlue">Для проверки напишите пример кода на основе классов Car и Vehicle ниже в блоке:</h4>
//
// ----

// %%
try
{
    Car car1 = new Car();
    car1.Color = "Red";
    car1.Speed = 60;   

    Console.WriteLine($"[Автомобиль 1]: {car1.Color} | Скорость: {car1.Speed} км/ч | Топливо на старте: {car1.FuelLevel}л");

    car1.Accelerate(45); 
    Console.WriteLine($"[После поездки]: Новая скорость = {car1.Speed} км/ч | Топливо уменьшилось до: {car1.FuelLevel}л");

    car1.Refuel(30);
    Console.WriteLine($"[После заправки]: Топливо пополнено до: {car1.FuelLevel}л");

    Console.WriteLine(new string('-', 65));

    Car car2 = new Car();
    car2.Color = "Black";
    car2.Speed = 90;
    car2.FuelLevel = 50;

    Console.WriteLine($"[Автомобиль 2]: {car2.Color} | Скорость: {car2.Speed} км/ч | Топливо: {car2.FuelLevel}л");

    car2.Accelerate(20);
    Console.WriteLine($"[После поездки 2]: Новая скорость = {car2.Speed} км/ч | Топливо уменьшилось до: {car2.FuelLevel}л");

    Console.WriteLine(new string('=', 65));

    Vehicle.DisplayTotalVehicles();

    Console.WriteLine("\nПопытка установить отрицательную скорость...");
    car2.Speed = -20;
}
catch (Exception ex)
{
    Console.WriteLine($"Ошибка компиляции данных -> {ex.Message}");
}

public class Vehicle
{
    private string _color;
    private int _speed;

    public string Color
    {
        get { return _color; }
        set { _color = value; }
    }

    public int Speed
    {
        get { return _speed; }
        set
        {
            if (value >= 0)
                _speed = value;
            else
                throw new ArgumentOutOfRangeException("Скорость не может быть отрицательной!");
        }
    }

    public static int TotalVehicles { get; private set; } = 0;

    public Vehicle()
    {
        TotalVehicles++;
    }

    public virtual void Accelerate(int delta)
    {
        Speed += delta;
    }

    public static void DisplayTotalVehicles()
    {
        Console.WriteLine($"Общее количество транспортных средств: {TotalVehicles}");
    }
}

public class Car : Vehicle
{
    private int _fuelLevel;

    public int FuelLevel
    {
        get { return _fuelLevel; }
        set { _fuelLevel = value; }
    }

    public Car() : base()
    {
        FuelLevel = 100; 
    }

    public override void Accelerate(int delta)
    {
        base.Accelerate(delta); 
        FuelLevel -= delta / 2; 
        if (FuelLevel < 0) FuelLevel = 0; 
    }

    public void Refuel(int amount)
    {
        FuelLevel += amount;
    }
}
// Out:
// [Автомобиль 1]: Red | Скорость: 60 км/ч | Топливо на старте: 100л
// [После поездки]: Новая скорость = 105 км/ч | Топливо уменьшилось до: 78л
// [После заправки]: Топливо пополнено до: 108л
// -----------------------------------------------------------------
// [Автомобиль 2]: Black | Скорость: 90 км/ч | Топливо: 50л
// [После поездки 2]: Новая скорость = 110 км/ч | Топливо уменьшилось до: 40л
// =================================================================
// Общее количество транспортных средств: 2
//
// Попытка установить отрицательную скорость...
// Ошибка компиляции данных -> Specified argument was out of the range of valid values. (Parameter 'Скорость не может быть отрицательной!')

// %% [markdown]
// <h4 style="color:Red">Задание:</h4>
//
// ----
//
// Ниже в блоке по примеру создайте базовый класс Animal и производные классы (2-3 например Dog, Cat и так далее) реализуйте структуру и объявление класса, включая свойства, геттеры и сеттеры, а также статические и обычными атрибуты и метода класса

// %%
using System;

try
{
    Dog myDog = new Dog();
    myDog.Name = "Рекс";
    myDog.Age = 4;
    myDog.Train(30);

    Console.WriteLine($"[Животное 1]: Собака {myDog.Name} | Возраст: {myDog.Age} лет | Послушание: {myDog.TrainingLevel}% | Энергия: {myDog.EnergyLevel}%");

    myDog.GrowOlder(2); 
    Console.WriteLine($"[После взросления]: Возраст собаки {myDog.Name}: {myDog.Age} лет | Энергия снизилась до: {myDog.EnergyLevel}%");

    myDog.Rest(15);
    Console.WriteLine($"[После отдыха]: Энергия собаки пополнена до: {myDog.EnergyLevel}%");

    Console.WriteLine(new string('-', 70));

    Cat myCat = new Cat();
    myCat.Name = "Мурзик";
    myCat.Age = 1;
    myCat.LoveLevel = 85;

    Console.WriteLine($"[Животное 2]: Кот {myCat.Name} | Возраст: {myCat.Age} лет | Уровень ласки: {myCat.LoveLevel}% | Энергия: {myCat.EnergyLevel}%");

    myCat.GrowOlder(3);
    Console.WriteLine($"[После взросления]: Возраст кота {myCat.Name}: {myCat.Age} лет | Энергия снизилась до: {myCat.EnergyLevel}%");

    Console.WriteLine(new string('-', 70));

    Parrot myParrot = new Parrot();
    myParrot.Name = "Кеша";
    myParrot.Age = 2;
    myParrot.LearnWord(12);

    Console.WriteLine($"[Животное 3]: Попугай {myParrot.Name} | Возраст: {myParrot.Age} лет | Словарный запас: {myParrot.VocabularySize} слов | Энергия: {myParrot.EnergyLevel}%");

    Console.WriteLine(new string('=', 70));

    Animal.DisplayTotalAnimals();

    Console.WriteLine("\nПопытка установить отрицательный возраст...");
    myCat.Age = -5;
}
catch (Exception ex)
{
    Console.WriteLine($"Ошибка компиляции данных -> {ex.Message}");
}


public class Animal
{
    private string _name;
    private int _age;

    public string Name
    {
        get { return _name; }
        set { _name = value; }
    }

    public int Age
    {
        get { return _age; }
        set
        {
            if (value >= 0)
                _age = value;
            else
                throw new ArgumentOutOfRangeException("Возраст животного не может быть отрицательным!");
        }
    }

    public static int TotalAnimals { get; private set; } = 0;

    public Animal()
    {
        TotalAnimals++;
    }

    public virtual void GrowOlder(int delta)
    {
        Age += delta;
    }

    public static void DisplayTotalAnimals()
    {
        Console.WriteLine($"Общее количество зарегистрированных животных: {TotalAnimals}");
    }
}

public class Dog : Animal
{
    private int _trainingLevel;
    private int _energyLevel;

    public int TrainingLevel
    {
        get { return _trainingLevel; }
        set { _trainingLevel = value; }
    }

    public int EnergyLevel
    {
        get { return _energyLevel; }
        set { _energyLevel = value; }
    }

    public Dog() : base()
    {
        TrainingLevel = 0;
        EnergyLevel = 100;
    }

    public override void GrowOlder(int delta)
    {
        base.GrowOlder(delta);
        EnergyLevel -= delta * 5;
        if (EnergyLevel < 0) EnergyLevel = 0;
    }

    public void Train(int amount)
    {
        TrainingLevel += amount;
    }

    public void Rest(int amount)
    {
        EnergyLevel += amount;
        if (EnergyLevel > 100) EnergyLevel = 100;
    }
}

public class Cat : Animal
{
    private int _loveLevel;
    private int _energyLevel;

    public int LoveLevel
    {
        get { return _loveLevel; }
        set { _loveLevel = value; }
    }

    public int EnergyLevel
    {
        get { return _energyLevel; }
        set { _energyLevel = value; }
    }

    public Cat() : base()
    {
        LoveLevel = 50;
        EnergyLevel = 100;
    }

    public override void GrowOlder(int delta)
    {
        base.GrowOlder(delta);
        EnergyLevel -= delta * 5;
        if (EnergyLevel < 0) EnergyLevel = 0;
    }
}

public class Parrot : Animal
{
    private int _vocabularySize;
    private int _energyLevel;

    public int VocabularySize
    {
        get { return _vocabularySize; }
        set { _vocabularySize = value; }
    }

    public int EnergyLevel
    {
        get { return _energyLevel; }
        set { _energyLevel = value; }
    }

    public Parrot() : base()
    {
        VocabularySize = 5;
        EnergyLevel = 100;
    }

    public override void GrowOlder(int delta)
    {
        base.GrowOlder(delta);
        EnergyLevel -= delta * 3;
        if (EnergyLevel < 0) EnergyLevel = 0;
    }

    public void LearnWord(int count)
    {
        VocabularySize += count;
    }
}
// Out:
// [Животное 1]: Собака Рекс | Возраст: 4 лет | Послушание: 30% | Энергия: 100%
// [После взросления]: Возраст собаки Рекс: 6 лет | Энергия снизилась до: 90%
// [После отдыха]: Энергия собаки пополнена до: 100%
// ----------------------------------------------------------------------
// [Животное 2]: Кот Мурзик | Возраст: 1 лет | Уровень ласки: 85% | Энергия: 100%
// [После взросления]: Возраст кота Мурзик: 4 лет | Энергия снизилась до: 85%
// ----------------------------------------------------------------------
// [Животное 3]: Попугай Кеша | Возраст: 2 лет | Словарный запас: 17 слов | Энергия: 100%
// ======================================================================
// Общее количество зарегистрированных животных: 3
//
// Попытка установить отрицательный возраст...
// Ошибка компиляции данных -> Specified argument was out of the range of valid values. (Parameter 'Возраст животного не может быть отрицательным!')
